# %%
import numpy as np
import akshare as ak
import mplfinance as mpf

# %%
stock_us_daily_df = ak.stock_us_daily(symbol="AAPL", adjust="qfq")
stock_us_daily_df
# Out:
#            date      open      high       low     close      volume
# 0    1984-09-07   -8.2914   -8.2898   -8.2925   -8.2914   2981600.0
# 1    1984-09-10   -8.2914   -8.2909   -8.2942   -8.2920   2346400.0
# 2    1984-09-11   -8.2909   -8.2875   -8.2909   -8.2898   5444000.0
# 3    1984-09-12   -8.2898   -8.2892   -8.2931   -8.2931   4773600.0
# 4    1984-09-13   -8.2870   -8.2864   -8.2870   -8.2870   7429600.0
# ...         ...       ...       ...       ...       ...         ...
# 9544 2024-10-03  225.1400  226.8050  223.3200  225.6700  34044127.0
# 9545 2024-10-04  227.9000  228.0000  224.1300  226.8000  37345068.0
# 9546 2024-10-07  224.5000  225.6900  221.3300  221.6900  39505338.0
# 9547 2024-10-08  224.3000  225.9800  223.2500  225.7700  31855693.0
# 9548 2024-10-09  225.2300  229.7500  224.8300  229.5400  33590963.0
#
# [9549 rows x 6 columns]

# %%
stock_us_daily_df = stock_us_daily_df.set_index(["date"])
stock_us_daily_df = stock_us_daily_df["2020-04-01": "2020-04-29"]
mpf.plot(stock_us_daily_df, type="candle", mav=(3, 6, 9), volume=True, show_nontrading=False)
